# %%
import control as ct
import numpy as np
import matplotlib.pyplot as plt
from plot_tools import plot_response

# %% [markdown]
# $P(s) = \frac{2}{s + 3}$
#
# $C(s) = K_p + K_i \frac{1}{s}$

# %%
kp = 3
ki = 1

P = ct.tf([2], [1, 3])
C = ct.tf([kp, ki], [1, 0])

display(P)
display(C)
# Out:
# TransferFunction(array([2]), array([1, 3]))
# TransferFunction(array([3, 1]), array([1, 0]))

# %%
Gyr = ct.feedback(P*C, 1)
display(Gyr)
# Out:
# TransferFunction(array([6, 2]), array([1, 9, 2]))

# %%
dt = 0.01
T = 10

t = np.arange(0, T, dt)

r = np.sign(np.sin(t))
outy = ct.forced_response(Gyr, t, r)

# %%
fig, ax = plot_response(t, r, outy.y[0]);
plt.show()

# %%
Gur = ct.feedback(C, P)
outu = ct.forced_response(Gur, t, r)
fig, ax = plot_response(t, r, outu.y[0]);
plt.show()
